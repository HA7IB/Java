# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("D:\Dataset\oasis_longitudinal.csv")
df
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (10, 5))
sns.heatmap(df.corr(), annot = True, cmap="summer")
# Out:
# <AxesSubplot:>

# %%
df=df.drop('Subject ID', axis= 1)

# %%
df=df.drop('MRI ID', axis= 1)

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Group']= le.fit_transform(df['Group'])
df['Group'].unique()
# Out:
# array([2, 1, 0])

# %%
df['M/F'].value_counts()
# Out:
# F    213
# M    160
# Name: M/F, dtype: int64

# %%
df['M/F']= df['M/F'].apply(lambda x: 1 if x == 'M' else (0 if x == 'F' else None))
df=df.rename(columns = {'M/F' : 'Gender'})

# %%
df= df.drop('Hand',axis=1)

# %%
df['SES']= df['SES'].replace(np.nan, 2)
df['SES'].unique()
# Out:
# array([2., 3., 4., 1., 5.])

# %%
df['MMSE']= df['MMSE'].replace(np.nan, 30)
df['MMSE'].unique()
# Out:
# array([27., 30., 23., 28., 22., 29., 24., 21., 16., 25., 26., 15., 20.,
#        19.,  7.,  4., 17., 18.])

# %%
X= df.drop('Group', axis=1)
y=df['Group']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state= 10)

# %%
from sklearn.naive_bayes import GaussianNB 
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.96

# %%
from sklearn.svm import SVC
SVM_rbf= SVC(kernel='rbf', random_state=10,gamma=3.0,C=1.5)
SVM_classifier=SVM_rbf.fit(X_train,y_train)
SVM_predict=SVM_classifier.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier 
Rfc = RandomForestClassifier()
Rfc.fit(X_train,y_train)
Rfc_predict = Rfc.predict(X_test)
Rfc.score(X_test,y_test)
# Out:
# 0.9466666666666667

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=100,learning_rate=1)
ada.fit(X_train, y_train)
ad_predict = ada.predict(X_test)
ada.score(X_test,y_test)
# Out:
# 0.6933333333333334

# %%
from xgboost import XGBClassifier
xb = XGBClassifier()
xb.fit(X_train,y_train)
xb_pred = xb.predict(X_test)
xb.score(X_test,y_test)
# Out:
# 0.9466666666666667

# %%
from sklearn.linear_model import LinearRegression 
LR = LinearRegression() 
LR.fit(X_train,y_train)
LR_predict = LR.predict(X_test)
LR.score(X_test,y_test)
# Out:
# 0.2929177580837691

# %%
from sklearn.linear_model import LogisticRegression 
Reg = LogisticRegression()
Reg.fit(X_train,y_train)
Reg_predict =Reg.predict(X_test)
Reg.score(X_test,y_test)
# Out:
# 0.7866666666666666

# %%
from sklearn.tree import DecisionTreeClassifier 
tree = DecisionTreeClassifier()
tree.fit(X_train,y_train)
tree_predict = tree.predict(X_test)
tree.score(X_test,y_test)
# Out:
# 0.9066666666666666

# %%
from sklearn.neighbors import KNeighborsRegressor
kn= KNeighborsRegressor(n_neighbors =20) 
kn.fit (X_train,y_train)
kn_predict= kn.predict(X_test)
kn.score(X_test,y_test)
# Out:
# -0.036500763747454146

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train,y_train)
Knn_predict = knn.predict(X_test)
knn.score(X_test,y_test)
# Out:
# 0.6

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
scaled_x = scaler.transform(X)

# %%
matrix = pd.crosstab(y_test, y_pred, rownames = ['Actual'], colnames = ['Predicted'])
print(matrix)
# Out:
# Predicted  0   1   2
# Actual
# 0          2   1   1
# 1          1  35   0
# 2          0   0  35

# %%
plt.figure(figsize = (6,3))
sns.heatmap(matrix.corr(), annot = True, cmap = 'OrRd')
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Predicted'>

# %%
matrix = pd.crosstab(y_test, Rfc_predict, rownames = ['Actual'], colnames = ['Predicted'])
print(matrix)
# Out:
# Predicted  0   1   2
# Actual
# 0          1   2   1
# 1          1  35   0
# 2          0   0  35

# %%
plt.figure(figsize = (10,6))
sns.heatmap(matrix.corr(), annot = True, cmap = 'OrRd')
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Predicted'>

# %%
from sklearn.metrics import classification_report,confusion_matrix
CM=confusion_matrix(y_test,Rfc_predict)
print("Confusion Matrix:\n",CM)
CR=classification_report(y_test,Rfc_predict)
print("Performance:\n",CR)
# Out:
# Confusion Matrix:
#  [[ 1  2  1]
#  [ 1 35  0]
#  [ 0  0 35]]
# Performance:
#                precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         4
#            1       0.95      0.97      0.96        36
#            2       0.97      1.00      0.99        35
#
#     accuracy                           0.95        75
#    macro avg       0.81      0.74      0.76        75
# weighted avg       0.93      0.95      0.94        75

# %%
df1=df
sns.pairplot(df1,hue='Group',size=2)

# %%
plt.figure ( figsize= (8,6) )
sns.countplot ( df.Group, data=df, hue='Gender' )
plt.title("Dementia Feature by Sex", size=20, weight='bold')
plt.ylabel ( 'Count' )
plt.xlabel ('', size = 16 )
plt.show()

# %%
plt.figure ( figsize= (8,6) )
sns.countplot ( df.EDUC, data=df )
plt.ylabel ('Count')
plt.show ()

# %%
sns.countplot(df.Group)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='count'>

# %%
# Histogram Distribution for continuous variables

plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.histplot(x='Age',data=df)
plt.subplot(2,3,2)
sns.histplot(x='MMSE',data=df)
plt.subplot(2,3,3)
sns.histplot(x='eTIV',data=df)
plt.subplot(2,3,4)
sns.histplot(x='nWBV',data=df)
plt.subplot(2,3,5)
sns.histplot(x='ASF',data=df)
# Out:
# <AxesSubplot:xlabel='ASF', ylabel='Count'>

# %%
sns.barplot(df.Group,df.Visit)
# Out:
# <AxesSubplot:xlabel='Group', ylabel='Visit'>

# %%
sns.countplot(df.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df['Visit'].corr(df['Age'])
# Out:
# 0.1832129281958907

# %%
sns.displot(df, x="MR Delay", hue="Group", kind="ecdf", height=5.27, aspect=11.7/8.27)

# %%
plt.figure ( figsize= (8,6) )
sns.countplot(df.Gender, hue=df.Group);

# %%
plt.figure ( figsize= (8,6) )
sns.countplot(df.MMSE, hue=df.Group);

# %%
sns.displot(data=df, x="ASF", hue="Group", kind="kde")

# %%
sns.displot(data=df, x="ASF", hue="Group", col="M/F", kind="kde")

# %%
sns.displot(data=df, x="eTIV", hue="Group", kind="kde")

# %%
sns.displot(data=df, x="nWBV", hue="Group", kind="kde")

# %%
sns.displot(data=df, x="EDUC", hue="Group", kind="kde")

# %%
sns.displot(data=df, x="Age", hue="Group", kind="kde")
